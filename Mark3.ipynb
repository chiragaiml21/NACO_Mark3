# %%
import re
import random
import json
import pandas as pd
import numpy as np
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from sklearn.preprocessing import LabelEncoder

# %%
with open("D://Study Material//GLATHON//PyTorch_model//Pyrates_bot-main//FINAL//back//intents.json", "r", encoding="utf8") as file:
    data = json.load(file)
intents = data["intents"]

# %%
df = pd.DataFrame(intents)
df
# Out:
#                          tag  \
# 0                   greeting
# 1                    goodbye
# 2                    creator
# 3               college_name
# 4                       name
# ..                       ...
# 131  cricket ground location
# 132       gd subway location
# 133      dispensary location
# 134         helipad location
# 135               unanswered
#
#                                               patterns  \
# 0    [hi, hi , Hi, hiiiiii, hiii, hii, hlo, how are...
# 1    [cya, see you, bye bye, See you later, Goodbye...
# 2    [what is the name of your developers, what is ...
# 3    [name of your college, your college name, what...
# 4    [name, your name, do you have a name, what are...
# ..                                                 ...
# 131  [cricket ground location, what is the location...
# 132  [gd subway location, gd subway, where is gd su...
# 133  [dispensary, how to reach dispensary, location...
# 134  [helipad location, how to reach helipad, where...
# 135  [able, about, above, abroad, according, accord...
#
#                                              responses
# 0                          [Hi there, how can I help?]
# 1                               [Sad to see you go :(]
# 2                                   [College students]
# 3                                   [G L A University]
# 4                                    [I am a Chatbot.]
# ..                                                 ...
# 131  [Hi there! you can reach the cricket ground  b...
# 132  [Hi there! you can reach the gd subway (comple...
# 133  [Hi there! you can reach the dispensary of uni...
# 134  [Hi there! you can reach the helipad in gla un...
# 135                      [Sorry, I do not understand!]
#
# [136 rows x 3 columns]

# %%
Patterns = []
Tags = []
lemmatizer = WordNetLemmatizer()

# %%
def preprocess_text(text):
    # Normalize text (convert to lowercase and remove non-alphanumeric characters)
    text = text.lower()
    text = re.sub(r"[^a-zA-Z0-9]", " ", text)   #Substitute the matched string in text with space.

    #Tokenize text
    tokenized_words = word_tokenize(text)

    # Lemmatization
    lemmatized_words = [lemmatizer.lemmatize(word) for word in tokenized_words]   #changing, Changed---->change

    # Join the preprocessed words back into a single string
    processed_text = " ".join(lemmatized_words)
    return processed_text

# %%
for intent in intents:
    tag = intent['tag']
    patterns = intent['patterns']
    for pattern in patterns:
        processed_pattern = preprocess_text(pattern)
        Patterns.append(processed_pattern)
        Tags.append(tag)

# %%
pd.DataFrame({'Patterns':Patterns, 'Tags':Tags})
# Out:
#      Patterns        Tags
# 0          hi    greeting
# 1          hi    greeting
# 2          hi    greeting
# 3     hiiiiii    greeting
# 4        hiii    greeting
# ...       ...         ...
# 2161   widely  unanswered
# 2162     word  unanswered
# 2163    world  unanswered
# 2164     youd  unanswered
# 2165    youre  unanswered
#
# [2166 rows x 2 columns]

# %%
# Tokenize words
tokenizer = Tokenizer(lower=True, split=' ')
tokenizer.fit_on_texts(Patterns)
word_index = tokenizer.word_index
vocab_size = len(word_index) + 1

# Encode the classes
encoder = LabelEncoder()
encoder.fit(Tags)
y = encoder.transform(Tags)

# Pad sequences
max_length = 20
X = pad_sequences(tokenizer.texts_to_sequences(Patterns), maxlen=max_length, padding="post")

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.2, random_state=0)

# %%
model = tf.keras.Sequential()
model.add(tf.keras.layers.Embedding(vocab_size, 128, input_length=max_length, trainable=True))
model.add(tf.keras.layers.Conv1D(128, 5, activation='relu'))
model.add(tf.keras.layers.GlobalMaxPooling1D())
model.add(tf.keras.layers.Dense(32, activation='relu'))
model.add(tf.keras.layers.Dropout(0.2))
model.add(tf.keras.layers.Dense(64, activation='relu'))
model.add(tf.keras.layers.Dropout(0.2))
model.add(tf.keras.layers.Dense(128, activation='relu'))
model.add(tf.keras.layers.Dropout(0.2))
model.add(tf.keras.layers.Dense(len(np.unique(y)), activation="softmax"))
model.compile(optimizer='adam', loss="sparse_categorical_crossentropy", metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 20, 128)           150144
#
#  conv1d (Conv1D)             (None, 16, 128)           82048
#
#  global_max_pooling1d (Globa  (None, 128)              0
#  lMaxPooling1D)
#
#  dense (Dense)               (None, 32)                4128
#
#  dropout (Dropout)           (None, 32)                0
#
#  dense_1 (Dense)             (None, 64)                2112
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  dense_2 (Dense)             (None, 128)               8320
#
#  dropout_2 (Dropout)         (None, 128)               0
#
#  dense_3 (Dense)             (None, 103)               13287
#
# =================================================================
# Total params: 260,039
# Trainable params: 260,039
# Non-trainable params: 0
# _________________________________________________________________

# %%
model_history = model.fit(X_train, y_train, epochs=100, verbose=1, validation_data=(X_test, y_test))
# Out:
# Epoch 1/100
# 55/55 [==============================] - 2s 12ms/step - loss: 3.8439 - accuracy: 0.3557 - val_loss: 3.1294 - val_accuracy: 0.3871
# Epoch 2/100
# 55/55 [==============================] - 0s 9ms/step - loss: 2.9161 - accuracy: 0.4053 - val_loss: 2.8018 - val_accuracy: 0.4078
# Epoch 3/100
# 55/55 [==============================] - 0s 9ms/step - loss: 2.6522 - accuracy: 0.4122 - val_loss: 2.6732 - val_accuracy: 0.4055
# Epoch 4/100
# 55/55 [==============================] - 0s 9ms/step - loss: 2.4886 - accuracy: 0.4145 - val_loss: 2.5306 - val_accuracy: 0.4055
# Epoch 5/100
# 55/55 [==============================] - 0s 9ms/step - loss: 2.3734 - accuracy: 0.4232 - val_loss: 2.4598 - val_accuracy: 0.4309
# Epoch 6/100
# 55/55 [==============================] - 0s 7ms/step - loss: 2.2701 - accuracy: 0.4388 - val_loss: 2.3992 - val_accuracy: 0.4355
# Epoch 7/100
# 55/55 [==============================] - 0s 7ms/step - loss: 2.1616 - accuracy: 0.4486 - val_loss: 2.3049 - val_accuracy: 0.4401
# Epoch 8/100
# 55/55 [==============================] - 0s 7ms/step - loss: 2.0469 - accuracy: 0.4706 - val_loss: 2.2272 - val_accuracy: 0.4355
# Epoch 9/100
# 55/55 [==============================] - 0s 7ms/step - loss: 1.9564 - accuracy: 0.4809 - val_loss: 2.1339 - val_accuracy: 0.4631
# Epoch 10/100
# 55/55 [==============================] - 0s 8ms/step - loss: 1.8811 - accuracy: 0.4913 - val_loss: 2.0548 - val_accuracy: 0.4700
# Epoch 11/100
# 55/55 [==============================] - 0s 7ms/step - loss: 1.8032 - accuracy: 0.5046 - val_loss: 2.1738 - val_accuracy: 0.4816
# Epoch 12/100
# 55/55 [==============================] - 0s 7ms/step - loss: 1.7443 - accuracy: 0.5058 - val_loss: 2.0024 - val_accuracy: 0.5000
# Epoch 13/100
# 55/55 [==============================] - 0s 7ms/step - loss: 1.6823 - accuracy: 0.5150 - val_loss: 2.0376 - val_accuracy: 0.5323
# Epoch 14/100
# 55/55 [==============================] - 0s 7ms/step - loss: 1.6073 - accuracy: 0.5358 - val_loss: 1.8656 - val_accuracy: 0.5323
# Epoch 15/100
# 55/55 [==============================] - 0s 8ms/step - loss: 1.5674 - accuracy: 0.5433 - val_loss: 1.8065 - val_accuracy: 0.5300
# Epoch 16/100
# 55/55 [==============================] - 0s 8ms/step - loss: 1.5231 - accuracy: 0.5520 - val_loss: 1.9123 - val_accuracy: 0.5507
100
# 55/55 [==============================] - 0s 8ms/step - loss: 0.8027 - accuracy: 0.7419 - val_loss: 1.1902 - val_accuracy: 0.7258
# Epoch 39/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.7883 - accuracy: 0.7361 - val_loss: 1.1081 - val_accuracy: 0.7535
# Epoch 40/100
# 55/55 [==============================] - 0s 6ms/step - loss: 0.7527 - accuracy: 0.7483 - val_loss: 1.0281 - val_accuracy: 0.7627
# Epoch 41/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.7504 - accuracy: 0.7529 - val_loss: 1.1075 - val_accuracy: 0.8065
# Epoch 42/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.7072 - accuracy: 0.7656 - val_loss: 1.1267 - val_accuracy: 0.7327
# Epoch 43/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.7331 - accuracy: 0.7685 - val_loss: 1.0256 - val_accuracy: 0.7765
# Epoch 44/100
# 55/55 [==============================] - 0s 8ms/step - loss: 0.7146 - accuracy: 0.7529 - val_loss: 1.1548 - val_accuracy: 0.7650
# Epoch 45/100
# 55/55 [==============================] - 0s 8ms/step - loss: 0.7563 - accuracy: 0.7523 - val_loss: 0.9604 - val_accuracy: 0.7673
# Epoch 46/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.7042 - accuracy: 0.7644 - val_loss: 1.0338 - val_accuracy: 0.7696
# Epoch 47/100
# 55/55 [==============================] - 0s 8ms/step - loss: 0.6958 - accuracy: 0.7639 - val_loss: 1.0397 - val_accuracy: 0.7880
# Epoch 48/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.6917 - accuracy: 0.7725 - val_loss: 1.0045 - val_accuracy: 0.7926
# Epoch 49/100
# 55/55 [==============================] - 0s 8ms/step - loss: 0.6430 - accuracy: 0.7887 - val_loss: 1.1101 - val_accuracy: 0.7166
# Epoch 50/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.6854 - accuracy: 0.7806 - val_loss: 0.9369 - val_accuracy: 0.8041
# Epoch 51/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.6540 - accuracy: 0.7719 - val_loss: 0.9514 - val_accuracy: 0.8157
# Epoch 52/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.6739 - accuracy: 0.7737 - val_loss: 0.9834 - val_accuracy: 0.8249
# Epoch 53/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.6433 - accuracy: 0.7875 - val_loss: 0.9571 - val_accuracy: 0.8456
# Epoch 54/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.6226 - accuracy: 0.7858 - val_loss: 0.9843 - val_accuracy: 0.8226
# Epoch 55/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.6228 - accuracy: 0.7950 - val_loss: 0.8735 - val_accuracy: 0.8433
# Epoch 56/100
# 55/55 [==============================] - 0s 8ms/step - loss: 0.6023 - accuracy: 0.8008 - val_loss: 0.8979 - val_accuracy: 0.8410
# Epoch 57/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.5900 - accuracy: 0.8002 - val_loss: 0.9144 - val_accuracy: 0.8318
# Epoch 58/100
# 55/55 [==============================] - 0s 8ms/step - loss: 0.5719 - accuracy: 0.8118 - val_loss: 0.8288 - val_accuracy: 0.8618
# Epoch 59/100
# 55/55 [==============================] - 0s 8ms/step - loss: 0.5804 - accuracy: 0.8170 - val_loss: 0.8960 - val_accuracy: 0.8548
# Epoch 60/100
# 55/55 [==============================] - 0s 8ms/step - loss: 0.5885 - accuracy: 0.8083 - val_loss: 0.9336 - val_accuracy: 0.8364
# Epoch 61/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.5711 - accuracy: 0.8199 - val_loss: 0.9149 - val_accuracy: 0.8249
# Epoch 62/100
# 55/55 [==============================] - 0s 6ms/step - loss: 0.5646 - accuracy: 0.8141 - val_loss: 0.9123 - val_accuracy: 0.8641
# Epoch 63/100
# 55/55 [==============================] - 0s 8ms/step - loss: 0.5578 - accuracy: 0.8118 - val_loss: 0.8965 - val_accuracy: 0.8433
# Epoch 64/100
# 55/55 [==============================] - 0s 8ms/step - loss: 0.5500 - accuracy: 0.8187 - val_loss: 1.0250 - val_accuracy: 0.7558
# Epoch 65/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.5759 - accuracy: 0.8089 - val_loss: 0.8940 - val_accuracy: 0.8364
# Epoch 66/100
# 55/55 [==============================] - 0s 8ms/step - loss: 0.5461 - accuracy: 0.8251 - val_loss: 0.8592 - val_accuracy: 0.8479
# Epoch 67/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0
100
# 55/55 [==============================] - 0s 8ms/step - loss: 0.3994 - accuracy: 0.8730 - val_loss: 0.8105 - val_accuracy: 0.8871
# Epoch 97/100
# 55/55 [==============================] - 0s 8ms/step - loss: 0.4407 - accuracy: 0.8678 - val_loss: 0.7531 - val_accuracy: 0.8848
# Epoch 98/100
# 55/55 [==============================] - 0s 9ms/step - loss: 0.4049 - accuracy: 0.8741 - val_loss: 0.8796 - val_accuracy: 0.7972
# Epoch 99/100
# 55/55 [==============================] - 0s 9ms/step - loss: 0.3987 - accuracy: 0.8730 - val_loss: 0.8124 - val_accuracy: 0.8525
# Epoch 100/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.4119 - accuracy: 0.8712 - val_loss: 0.7429 - val_accuracy: 0.8894

# %%
model_history.history.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
import matplotlib.pyplot as plt 

accuracy = model_history.history['accuracy']
val_accuracy = model_history.history['val_accuracy']
loss = model_history.history['loss']
val_loss = model_history.history['val_loss']

epochs = range(len(accuracy))

fig = plt.figure(figsize = (10, 10), edgecolor = 'Black')
ax1 = fig.add_subplot(2, 1, 1)
ax2 = fig.add_subplot(2, 1, 2)

ax1.plot(epochs, accuracy, label = 'Training Accuracy')
ax1.plot(epochs, val_accuracy, label = 'Validation Accuracy')
ax1.set_title("Training and Validation accuracy", fontsize = 20)
ax1.set_ylabel("Accuracy", fontsize = 15)
ax1.legend()

ax2.plot(epochs, loss, label = 'Training Loss')
ax2.plot(epochs, val_loss, label = 'Validation Loss')
ax2.set_title("Training and Validation Loss", fontsize = 20)
ax2.set_ylabel("Loss", fontsize = 15)
ax2.legend()

plt.show()

# %%
print(accuracy[-1])
# Out:
# 0.8712471127510071

# %%
def get_response():
    while True:
        print("Enter your message:")
        message = input()
        message = preprocess_text(message)
        if message == "quit" or message == "stop":
            break
        message = pad_sequences(tokenizer.texts_to_sequences([message]), maxlen=max_length, padding="post")
        prediction = model.predict(message)
        tag = encoder.inverse_transform([np.argmax(prediction)])
        for intent in intents:
            if intent['tag'] == tag:
                print(random.choice(intent['responses']))

# %%
get_response()
# Out:
# Enter your message:
# 1/1 [==============================] - 0s 25ms/step
# Hi there, how can I help?
# Enter your message:
# 1/1 [==============================] - 0s 25ms/step
# G L A University
# Enter your message:
# 1/1 [==============================] - 0s 27ms/step
# G L A University
# Enter your message:
# 1/1 [==============================] - 0s 22ms/step
# Sorry, I do not understand!
# Enter your message:
# 1/1 [==============================] - 0s 19ms/step
# I am a Chatbot.
# Enter your message:
# 1/1 [==============================] - 0s 26ms/step
# G L A University
# Enter your message:
# 1/1 [==============================] - 0s 38ms/step
# Hi there, how can I help?
# Enter your message:
# 1/1 [==============================] - 0s 22ms/step
# Hi there! you can reach the academic block 1 by navigating through the mentioned link:https://goo.gl/maps/8sX4x88zZS66p3waA
# Hi there! you can reach the academic block 1 by navigating through the mentioned link:https://goo.gl/maps/8sX4x88zZS66p3waA
# Enter your message:
# 1/1 [==============================] - 0s 22ms/step
# Hi there! you can reach the h block by navigating through the mentioned link:https://maps.app.goo.gl/GcaUmE2uJvEWx93V9
# Hi there! you can reach the h block by navigating through the mentioned link:https://maps.app.goo.gl/GcaUmE2uJvEWx93V9
# Enter your message:
